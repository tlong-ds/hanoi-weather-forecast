# %% [markdown]
# <a href="https://colab.research.google.com/github/tlong-ds/hanoi-weather-forecast/blob/dev/run_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path = "hanoi-weather-forecast"
import os
os.chdir(path)
print(f"Changed current working directory to: {os.getcwd()}")
# Out:
# Changed current working directory to: /content/hanoi-weather-forecast

# %%
# %pip install scikit-build-core
# Out:
# Requirement already satisfied: scikit-build-core in /usr/local/lib/python3.12/dist-packages (0.11.6)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from scikit-build-core) (25.0)
# Requirement already satisfied: pathspec>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-build-core) (0.12.1)

# %%
# %pip uninstall -y lightgbm
# !apt-get install -y git cmake build-essential libboost-dev libboost-system-dev libboost-filesystem-dev
# !git clone --recursive https://github.com/microsoft/LightGBM
# %cd LightGBM
# %mkdir build
# %cd build
# !cmake -DUSE_GPU=1 -DUSE_CUDA=1 ..
# !make -j$(nproc)
# %cd ../python-package
# Out:
# WARNING: Skipping lightgbm as it is not installed.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# libboost-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-filesystem-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-system-dev is already the newest version (1.74.0.3ubuntu7).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.15).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# fatal: destination path 'LightGBM' already exists and is not an empty directory.
# /content/hanoi-weather-forecast/LightGBM
# mkdir: cannot create directory ‘build’: File exists
# /content/hanoi-weather-forecast/LightGBM/build
# -- OpenCL include directory: /usr/include
# CMake Warning (dev) at CMakeLists.txt:195 (find_package):
#   Policy CMP0167 is not set: The FindBoost module is removed.  Run "cmake
#   --help-policy CMP0167" for policy details.  Use the cmake_policy command to
#   set the policy and suppress this warning.
#
# This warning is for project developers.  Use -Wno-dev to suppress it.
#
# -- CUDA_ARCHITECTURES: 60-real;61-real;62-real;70-real;75-real;80-real;86-real;87-real;89-real;90-real;90-virtual
# -- CMAKE_CUDA_FLAGS:  -Xcompiler=-fopenmp -Xcompiler=-fPIC -Xcompiler=-Wall -O3 -lineinfo
# -- Using _mm_prefetch
# -- Using _mm_malloc
# -- Configuring done (0.1s)
# -- Generating done (0.0s)
# -- Build files have been written to: /content/hanoi-weather-forecast/LightGBM/build
# [  1%] Built target lightgbm_capi_objs
# [ 91%] Built target lightgbm_objs
# [ 94%] Built target _lightgbm
# [100%] Built target lightgbm
# /content/hanoi-weather-forecast/LightGBM/python-package

# %%
# %pip install . --no-build-isolation
# Out:
# Processing /content/hanoi-weather-forecast/LightGBM/python-package
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# %pip install optuna clearml
# Out:
# Collecting optuna
#   Using cached optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting clearml
#   Using cached clearml-2.0.2-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.1)
# Collecting colorlog (from optuna)
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (25.4.0)
# Collecting furl>=2.0.0 (from clearml)
#   Using cached furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (4.25.1)
# Collecting pathlib2>=2.3.0 (from clearml)
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: psutil>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from clearml) (5.9.5)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from clearml) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.9.0.post0)
# Requirement already satisfied: pyjwt<2.11.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.10.1)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.5.0)
# Requirement already satisfied: Pillow>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (11.3.0)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.12/dist-packages (from clearml) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from clearml) (2.32.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->clearml) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->clearml) (0.28.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 20.1 MB/s eta 0:00:00
# Downloading clearml-2.0.2-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.0 MB/s eta 0:00:00
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pathlib2, orderedmultidict, colorlog, furl, optuna, clearml
# Successfully installed clearml-2.0.2 colorlog-6.10.1 furl-2.1.4 optuna-4.5.0 orderedmultidict-1.0.1 pathlib2-2.3.7.post1

# %%
# %pip install catboost xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (1.2.8)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.1)
# Collecting lightgbm
#   Using cached lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (8.5.0)
# Using cached lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0

# %%
# %run run_tuning.py
# Out:
# ---------------------------------------------------------------------------
# MissingConfigError                        Traceback (most recent call last)
# /content/hanoi-weather-forecast/run_tuning.py in <module>
#      16
#      17 # =============== BƯỚC 1: KHỞI TẠO CLEARML TASK ===============
# ---> 18 task = Task.init(
#      19     project_name="HanoiTemp_Forecast",
#      20     task_name="Optuna_Tuning_4Models"
#
# /usr/local/lib/python3.12/dist-packages/clearml/task.py in init(cls, project_name, task_name, task_type, tags, reuse_last_task_id, continue_last_task, output_uri, auto_connect_arg_parser, auto_connect_frameworks, auto_resource_monitoring, auto_connect_streams, deferred_init)
#     638                 elif not is_sub_process_task_id:
#     639                     try:
# --> 640                         task = cls._create_dev_task(
#     641                             default_project_name=project_name,
#     642                             default_task_name=task_name,
#
# /usr/local/lib/python3.12/dist-packages/clearml/task.py in _create_dev_task(cls, default_project_name, default_task_name, default_task_type, tags, reuse_last_task_id, continue_last_task, detect_repo, auto_connect_streams)
#    4380         # create a new task
#    4381         if not default_task_id:
# -> 4382             task = cls(
#    4383                 private=cls.__create_protection,
#    4384                 project_name=default_project_name,
#
# /usr/local/lib/python3.12/dist-packages/clearml/task.py in __init__(self, private, **kwargs)
#     244         self._repo_detect_lock = threading.RLock()
#     245
# --> 246         super(Task, self).__init__(**kwargs)
#     247         self._arguments = _Arguments(self)
#     248         self._logger = None
#
# /usr/local/lib/python3.12/dist-packages/clearml/backend_interface/task/task.py in __init__(self, session, task_id, log, project_name, task_name, task_type, log_to_backend, raise_on_validation_errors, force_create)
#     197         task_id = self._resolve_task_id(task_id, log=log) if not force_create else None
#     198         self.__edit_lock = None
# --> 199         super(Task, self).__init__(id=task_id, session=session, log=log)
#     200         self._project_name = None
#     201         self._storage_uri = None
#
# /usr/local/lib/python3.12/dist-packages/clearml/backend_interface/base.py in __init__(self, id, session, log, **kwargs)
#     179 class IdObjectBase(InterfaceBase):
#     180     def __init__(self, id: str, session: Session = None, log: logging.Logger = None, **kwargs: Any) -> None:
# --> 181         super(IdObjectBase, self).__init__(session, log, **kwargs)
#     182         self._data = None
#     183         self._id = None
#
# /usr/local/lib/python3.12/dist-packages/clearml/backend_interface/base.py in __init__(self, session, log, **kwargs)
#      45     def __init__(self, session: Session = None, log: logging.Logger = None, **kwargs: Any) -> None:
#      46         super(InterfaceBase, self).__init__()
# ---> 47         self._session = session or self._get_default_session()
#      48         self._log = log or self._create_log()
#      49
#
# /usr/local/lib/python3.12/dist-packages/clearml/backend_interface/base.py in _get_default_session(cls)
#     150     def _get_default_session(cls) -> Session:
#     151         if not InterfaceBase._default_session:
# --> 152             InterfaceBase._default_session = Session(
#     153                 initialize_logging=False,
#     154                 config=config_obj,
#
# /usr/local/lib/python3.12/dist-packages/clearml/backend_api/session/session.py in __init__(self, worker, api_key, secret_key, host, logger, verbose, config, http_retries_config, **kwargs)
#     175             self.config = ConfigWrapper._init()
#     176
# --> 177         self._connect()
#     178
#     179     @classmethod
#
# /usr/local/lib/python3.12/dist-packages/clearml/backend_api/session/session.py in _connect(self)
#     239
#     240         if not self.secret_key and not self.access_key and not self.__auth_token:
# --> 241             raise MissingConfigError()
#     242
#     243         super(Session, self).__init__(
#
# MissingConfigError: It seems ClearML is not configured on this machine!
# To get started with ClearML, setup your own 'clearml-server' or create a free account at https://app.clear.ml
# Setup instructions can be found here: https://clear.ml/docs
