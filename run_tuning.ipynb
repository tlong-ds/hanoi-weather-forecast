# %% [markdown]
# <a href="https://colab.research.google.com/github/tlong-ds/hanoi-weather-forecast/blob/dev/run_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
# Out:
# test

# %%
# %rm -rf hanoi-weather-forecast
# !git clone https://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@github.com/tlong-ds/hanoi-weather-forecast
# %cd hanoi-weather-forecast
# !git checkout dev-long
# Out:
# Cloning into 'hanoi-weather-forecast'...
# remote: Enumerating objects: 815, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Enumerating objects: 815, done.[K
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 815 (delta 40), reused 71 (delta 27), pack-reused 722 (from 1)
# Receiving objects: 100% (815/815), 53.86 MiB | 15.44 MiB/s, done.
# remote: Total 815 (delta 40), reused 71 (delta 27), pack-reused 722 (from 1)
# Receiving objects: 100% (815/815), 53.86 MiB | 15.44 MiB/s, done.
# Resolving deltas: 100% (352/352), done.
# Resolving deltas: 100% (352/352), done.
# /content/hanoi-weather-forecast/hanoi-weather-forecast/hanoi-weather-forecast/hanoi-weather-forecast/hanoi-weather-forecast/hanoi-weather-forecast
# ...

# %%
# %pip install scikit-build-core optuna clearml catboost xgboost

# %%
# Out:
# ✓ ClearML credentials configured

# %%
# %run src/daily_forecast_model/tune.py
# Out:
# [I 2025-11-16 03:14:17,581] A new study created in memory with name: Stage1_Architecture_Selection
# ...
# 🚀 TWO-STAGE HYPERPARAMETER TUNING PIPELINE
# ...
#
# ...
# STAGE 1: ARCHITECTURE SELECTION
# ...
# Goal: Find the best model architecture
# Method: Test 4 models with 40 trials
# Features: Using combined features (representative)
# ...
#
# ...
# STAGE 1: Loading COMBINED features for architecture selection
# ...
# Loading data from: processed_data/target_t_3
# ✅ Loaded combined features: 43 features
# ✅ Train samples: 2659, Dev samples: 584
#
# Running 40 trials for architecture selection...
#   0%|          | 0/40 [00:00<?, ?it/s]
#   Trial   0 | RandomForest: RMSE=2.6774, MAE=2.0937
# [I 2025-11-16 03:14:42,356] Trial 0 finished with value: 2.677439655106794 and parameters: {'model_name': 'RandomForest', 'rf_n_estimators': 300, 'rf_max_depth': 12, 'rf_min_samples_split': 2}. Best is trial 0 with value: 2.677439655106794.
#   Trial   1 | CatBoost    : RMSE=2.5302, MAE=1.9828
# ...

# %%
# %ls
# Out:
# catboost_info/                requirements.txt
# chainlit.md                   results/
# data_processing_hourly/       run_tuning.ipynb
# dataset/                      src/
# hanoi_weather_forecast.ipynb  test_onnx_runtime_gpu.py
# ml_model.py                   train_and_evaluate_model_hourly.py
# plots/                        trained_models/
# preprocessed_hourly.py        tutorials/
# processed_data/               uidemo.py
# README.md

# %%
with open("results/stage1_architecture_selection.json", "r") as f:
    print(f.read())
# Out:
# {
#   "best_architecture": "CatBoost",
#   "best_rmse": 2.502656671212861,
#   "best_params": {
#     "model_name": "CatBoost",
#     "cat_iterations": 700,
#     "cat_depth": 4,
#     "cat_learning_rate": 0.01,
#     "cat_l2_leaf_reg": 3.0
#   }
# }

# %%
with open("results/stage2_best_params_per_target.json", "r") as f:
    print(f.read())
# Out:
# {
#   "t+1": {
#     "model": "CatBoost",
#     "feature_type": "SHORT-TERM",
#     "n_features": 34,
#     "params": {
#       "iterations": 777,
#       "depth": 5,
#       "learning_rate": 0.026258062334984796,
#       "l2_leaf_reg": 1.2300235014118366,
#       "subsample": 0.6024387745307975,
#       "colsample_bylevel": 0.7820411612696558,
#       "min_data_in_leaf": 8
#     },
#     "best_rmse": 1.4886751893405843
#   },
#   "t+2": {
#     "model": "CatBoost",
#     "feature_type": "COMBINED",
#     "n_features": 43,
#     "params": {
#       "iterations": 593,
#       "depth": 3,
#       "learning_rate": 0.061792520222287727,
#       "l2_leaf_reg": 4.658044160279362,
#       "subsample": 0.6070813994504971,
#       "colsample_bylevel": 0.926215567734238,
#       "min_data_in_leaf": 15
#     },
#     "best_rmse": 2.168812543616968
#   },
#   "t+3": {
#     "model": "CatBoost",
#     "feature_type": "COMBINED",
#     "n_features": 43,
#     "params": {
# ...

# %%
# %cd hanoi-weather-forecast
# !git add results
# !git commit -m "Add tuning results"
# !git push origin dev-long
# Out:
# /content/hanoi-weather-forecast
# fatal: pathspec 'results' did not match any files
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@fb3f97ceb8ac.(none)')
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@fb3f97ceb8ac.(none)')
# error: src refspec dev-long does not match any
# error: failed to push some refs to 'https://github.com/tlong-ds/hanoi-weather-forecast'
# error: src refspec dev-long does not match any
# ...

# %%
# Out:
# hanoi-weather-forecast	sample_data
