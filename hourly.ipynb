# %%
# %run train_and_evaluate_model_hourly.py
# Out:
# Loaded shapes: X_train (65800, 38) | y_train (65800, 24) | X_dev (14113, 38) | y_dev (14113, 24)
#
# Training RandomForest (MultiOutput, hourly)…
# Training done.
#
# Evaluating on dev…
# Dev  Avg MAE: 1.2500 | Avg RMSE: 2.9906
#
# Saved:
#   Metrics-> c:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast\data_processing_hourly\model_evaluation_results_hourly.csv
#   Plot  -> c:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast\data_processing_hourly\metrics_bar_hourly.png
#   Plot  -> c:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast\data_processing_hourly\pred_vs_actual_hourly.png
#   Plot  -> c:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast\data_processing_hourly\feature_importance_hourly.png
#
# All done.

# %%
#alalalalla
