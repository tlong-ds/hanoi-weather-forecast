# %%
# %run preprocessed_hourly.py
# Out:
# >> RUNNING FILE: c:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast\preprocessed_hourly.py
# >> NOTEBOOK CWD: c:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast
# >> Will save EVERYTHING to (flat): c:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast\data_processing_hourly
# >> Loading hourly data …
# >> Loaded: (94248, 23) from C:\Users\lenovo\Downloads\python exercises\ml 2\hanoi-weather-forecast\dataset\hn_hourly.csv
# >> Feature engineering (hourly) …
# >> Creating 24-step hourly targets …
# >> Target columns (sample): ['target_temp_t+1h', 'target_temp_t+2h', 'target_temp_t+3h', 'target_temp_t+4h', 'target_temp_t+5h'] … total=24
# >> Split into train/dev/test …
# >> Dropping NaNs from critical columns …
# >> Train after drop: (65800, 76)
# >> Selecting numeric features …
# >> Selected numeric: 30
# >> Fitting preprocessing …
# ...

# %%
# %run train_and_evaluate_model_hourly.py
# máy phế không run nổi
# Out:
# Loaded shapes: X_train (65800, 38) | y_train (65800, 24) | X_dev (14113, 38) | y_dev (14113, 24)
#
# Training RandomForest (MultiOutput, hourly)…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Downloads\python exercises\ml 2\hanoi-weather-forecast\train_and_evaluate_model_hourly.py:55
#      53 # ---- 4) Train ----
#      54 print("\nTraining RandomForest (MultiOutput, hourly)…")
# ---> 55 model.fit(X_tr, y_tr)
#      56 print("Training done.")
#      58 # ---- 5) Evaluate trên dev ----
#
# File c:\Users\lenovo\miniconda3\envs\ml_env\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# ...
