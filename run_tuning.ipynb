# %% [markdown]
# <a href="https://colab.research.google.com/github/tlong-ds/hanoi-weather-forecast/blob/dev/run_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
# Out:
# test

# %%
path = "hanoi-weather-forecast"
import os
os.chdir(path)
print(f"Changed current working directory to: {os.getcwd()}")
# Out:
# Changed current working directory to: /content/hanoi-weather-forecast

# %%
# %pip install scikit-build-core optuna clearml catboost xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.9 MB/s eta 0:00:00
# ...

# %%
# %run run_tuning.py
# Out:
# ClearML Task: created new task id=0940e10f77c64e6cac9218609a07200b
# ClearML results page: https://app.clear.ml/projects/55b661140cf84a0387d505f95016cdd6/experiments/0940e10f77c64e6cac9218609a07200b/output/log
# [I 2025-11-10 16:31:11,187] A new study created in memory with name: 4Models_Tuning_TrainDev
# ✓ Loaded train set successfully!
#   X_train shape: (2659, 43)
#   y_train shape: (2659, 5)
# ✓ Loaded dev set successfully!
#   X_dev shape: (584, 43)
#   y_dev shape: (584, 5)
# ✅ Dữ liệu train: (2659, 43), target: (2659, 5)
# ✅ Dữ liệu dev: (584, 43), target: (584, 5)
#   0%|          | 0/60 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
best_param = {'model_name': 'CatBoost', 'iterations': 500, 'depth': 4, 'learning_rate': 0.014185371615744864, 'l2_leaf_reg': 4.260673208870433, 'subsample': 0.9781299341552055}
with open('best_params.json', 'w') as f:
    import json
    json.dump(best_param, f)
